# %%
import os

processed_dir = "../dataset/processed"

for class_name in ["glioma", "meningioma", "pituitary"]:

    folder = os.path.join(processed_dir, class_name)

    count = len([
        f for f in os.listdir(folder)
        if f.lower().endswith(".png")
    ])

    print(f"{class_name}: {count}")
# Out:
# glioma: 1426
# meningioma: 708
# pituitary: 930
